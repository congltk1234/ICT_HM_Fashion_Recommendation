# %% [markdown]
# # Get data from Kaggle Competition

# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import json
# Serializing json
kaggle_tokken = json.dumps({"username":"sthnhcng","key":"3764ef56f50a4eb32c50a9f6257e2214"})
# Writing to kaggle.json
with open("kaggle.json", "w") as outfile:
    outfile.write(kaggle_tokken)

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c h-and-m-personalized-fashion-recommendations
# Out:
# ...
# 100% 28.7G/28.7G [03:46<00:00, 186MB/s]
# 100% 28.7G/28.7G [03:46<00:00, 136MB/s]

# %%
# !unzip "/content/h-and-m-personalized-fashion-recommendations.zip" -d "/content/HM"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/HM/images/065/0653188010.jpg
#   inflating: /content/HM/images/065/0653188011.jpg
#   inflating: /content/HM/images/065/0653188016.jpg
#   inflating: /content/HM/images/065/0653188017.jpg
#   inflating: /content/HM/images/065/0653188018.jpg
#   inflating: /content/HM/images/065/0653188022.jpg
#   inflating: /content/HM/images/065/0653188023.jpg
#   inflating: /content/HM/images/065/0653188024.jpg
#   inflating: /content/HM/images/065/0653188025.jpg
#   inflating: /content/HM/images/065/0653188026.jpg
#   inflating: /content/HM/images/065/0653188027.jpg
#   inflating: /content/HM/images/065/0653188031.jpg
#   inflating: /content/HM/images/065/0653188032.jpg
#   inflating: /content/HM/images/065/0653201001.jpg
#   inflating: /content/HM/images/065/0653208001.jpg
#   inflating: /content/HM/images/065/0653208002.jpg
#   inflating: /content/HM/images/065/0653208004.jpg
# ...

# %% [markdown]
# Move to Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp /content/HM/articles.csv /content/drive/MyDrive/HM/articles.csv
# !cp /content/HM/customers.csv /content/drive/MyDrive/HM/customers.csv
# !cp /content/HM/transactions_train.csv /content/drive/MyDrive/HM/transactions_train.csv

# %%
# !cp /content/HM/sample_submission.csv /content/drive/MyDrive/HM/sample_submission.csv

# %%
# !zip -r "/content/drive/MyDrive/HM/HMdata.zip" "new"
# Out:
#   adding: new/ (stored 0%)
#   adding: new/sample_submission.csv (deflated 80%)
#   adding: new/articles.csv (deflated 88%)
#   adding: new/customers.csv (deflated 51%)
#   adding: new/transactions_train.csv
#  (deflated 82%)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm

# %%
articles = pd.read_csv("/content/HM/articles.csv")
customers = pd.read_csv("/content/HM/customers.csv")
transactions = pd.read_csv("/content/HM/transactions_train.csv")

# %%
articles
# Out:
#         article_id  product_code               prod_name  product_type_no  \
# 0        108775015        108775               Strap top              253
# 1        108775044        108775               Strap top              253
# 2        108775051        108775           Strap top (1)              253
# 3        110065001        110065       OP T-shirt (Idro)              306
# 4        110065002        110065       OP T-shirt (Idro)              306
# ...            ...           ...                     ...              ...
# 105537   953450001        953450  5pk regular Placement1              302
# 105538   953763001        953763       SPORT Malaga tank              253
# 105539   956217002        956217         Cartwheel dress              265
# 105540   957375001        957375        CLAIRE HAIR CLAW               72
# 105541   959461001        959461            Lounge dress              265
#
#        product_type_name  product_group_name  graphical_appearance_no  \
# ...
